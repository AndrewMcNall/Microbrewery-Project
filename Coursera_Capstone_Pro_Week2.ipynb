# %% [markdown]
# # Capstone Project
#
# # Portland, Oregon Microbrewery Market (week 2)
#
# ### Applied Data Science Capstone for IBM/Coursera

# %% [markdown]
# ## Table of Contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>
#
# Portland is the largest city in Oregon. Portland is located in the Northwest section of the state at the junction of the Willamette and Columbia rivers. Portland is a growing, attractive metropolis with a diverse economy. The region continues to attract entreprenuers, innovators and IT professionals.
#
# Microbrewers have found the culture of Portland extremely friendly to their craft brews. In fact, the Oregon Craft Beer Association claims that **Portland**, with 117 breweries in the greater metro area as of 2018, **has more breweries than any other city in the world** https://oregoncraftbeer.org/facts/.
#
# The focus of this project is to discover whether or not any locations exist in Portland that are not oversaturated with microbreweries. This report will target specifically entrepreneurs interested in opening a **microbrewery** in **Portland**, Oregon.
#
# Since Portland has more microbreweries than any other city in the world, we will look for **locations with no microbrewery in the vicinity**. We will interpret this to mean no other microbrewery within 500 meters, or approximately 5 min walk. We'll be **looking as close as possible to the center of Portland**. Additionally, we'll **exclude the suburbs** from our search because they are largely residential areas with fewer vistors and fewer businesses and industries. And, we'll exclude other types of restaurants from our search as patrons of microbreweries tend to choose among the microbreweries available rathern than between a microbrewery and another type of restaurant.

# %% [markdown]
# ##  Data <a name="data"></a>
#
# Given how we've framed the problem the following factors will influence our decision:
#
#   * The number of microbreweries centered around downtown Portland.
#   * The distance between each microbrewery and its next closest neighbor.
#
# The required information will be extracted from the following data sources:
#
#   * Coordinates of downtown Portland and distances between microbreweries will be obtained using **GeoPy Geocoder**.
#   * The names, addresses and coordinates of microbreweries will be obtained through **Foursquare API**.

# %% [markdown]
# ### Downtown Portland
#
# We'll start by finding a latitude and longitude for downtown Portland using GeoPy's Nominatim to convert an address into coordinates.
#
# First, we load the Nominatim function:

# %%
from geopy.geocoders import Nominatim # convert address into latitude and longitude

# %% [markdown]
# Then we run the function for the address 'Portland, OR'.

# %%
address = 'Portland, OR'

geolocator = Nominatim(user_agent="foursquare_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Portland are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Portland are 45.5202471, -122.6741949.

# %% [markdown]
# Next we import the Folium library for map construction and create a map of Portland using the coordinates we derived in the last step.

# %%
# map construction library

import folium

# %%
# create map of Portland using latitude and longitude values

map_portland = folium.Map(location=[latitude, longitude], zoom_start = 13) 

map_portland
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a map centered on downtown Portland let's procure the data on microbreweries from Foursquare.

# %% [markdown]
# ### Foursquare API

# %% [markdown]
# First we define our Foursquare credentials:

# %%
CLIENT_ID ="3U5ZTVO5FPT4Z1JJWRMPOCW1XG2DNSI3OR4JKIQFNIIDUZNC"
CLIENT_SECRET ="TQ5QY3SW5QTRW10SO4IGDLIAPO45IEUUHIIDENMJGQHNPEMR"

# %% [markdown]
# Next we define the other parameters needed to extract the microbrewery data, including version, radius and limit. Microbreweries have their own category id, so we'll use it to extract data on only microbreweries.

# %%
Version = '20180605'

categoryId = '50327c8591d4c4b30a586d5d'

radius = 6000

limit = 100

data = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId={}&v={}&radius={}&limit={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, categoryId, Version, radius, limit)

data
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3U5ZTVO5FPT4Z1JJWRMPOCW1XG2DNSI3OR4JKIQFNIIDUZNC&client_secret=TQ5QY3SW5QTRW10SO4IGDLIAPO45IEUUHIIDENMJGQHNPEMR&ll=45.5202471,-122.6741949&categoryId=50327c8591d4c4b30a586d5d&v=20180605&radius=6000&limit=100'

# %% [markdown]
# Let's import the Requests module and start unpacking our data.

# %%
import requests

results = requests.get(data).json()

results
# Out:
# {'meta': {'code': 200, 'requestId': '5e8ff8d89da7ee001b40a948'},
#  'response': {'venues': [{'id': '48837e4ef964a52036511fe3',
#     'name': 'Deschutes Brewery Portland Public House',
#     'location': {'address': '210 NW 11th Ave',
#      'crossStreet': 'at NW Davis St',
#      'lat': 45.524544086316254,
#      'lng': -122.68198230367531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.524544086316254,
#        'lng': -122.68198230367531}],
#      'distance': 773,
#      'postalCode': '97209',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['210 NW 11th Ave (at NW Davis St)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '36780574'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5e486a88fda02b000899b294',
#     'name': 'Gorges Beer: The Trailhead',
#     'location': {'address': '2705 SE Ankeny St',
#      'lat': 45.522343,
#      'lng': -122.638284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.522343,
#        'lng': -122.638284}],
#      'distance': 2810,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2705 SE Ankeny St',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5cbf7b91b399f7002c94b190',
#     'name': 'Away Days Brewing',
#     'location': {'address': '1516 SE 10th Ave',
#      'lat': 45.511985938255236,
#      'lng': -122.6559805870056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.511985938255236,
#        'lng': -122.6559805870056}],
#      'distance': 1692,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1516 SE 10th Ave',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1406736',
#      'url': 'https://www.grubhub.com/restaurant/away-days-brewing-1516-se-10th-ave-portland/1406736?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1406736',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5b37dc162a7ab6002ca58d9f',
#     'name': 'Baerlic Brewing Beer Hall at the Barley Pod',
#     'location': {'address': '6035 NE Halsey St',
#      'crossStreet': 'at NE 60th Ave',
#      'lat': 45.53389890556244,
#      'lng': -122.60132621324176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.53389890556244,
#        'lng': -122.60132621324176}],
#      'distance': 5882,
#      'postalCode': '97213',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['6035 NE Halsey St (at NE 60th Ave)',
#       'Portland, OR 97213',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5aadc02ee07550183870d5ee',
#     'name': '10 Barrel',
#     'location': {'address': '1 N Center Court St',
#      'lat': 45.531254,
#      'lng': -122.667361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.531254,
#        'lng': -122.667361}],
#      'distance': 1336,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1 N Center Court St',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5c577261492814002c1fe219',
#     'name': 'Leikam Tap Room',
#     'location': {'address': '5812 E Burnside St',
#      'lat': 45.522624,
#      'lng': -122.604116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.522624,
#        'lng': -122.604116}],
#      'distance': 5472,
#      'postalCode': '97215',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['5812 E Burnside St',
#       'Portland, OR 97215',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5a73da1c35f9835fcb42fda1',
#     'name': 'Look Long Brewing Company',
#     'location': {'lat': 45.57057,
#      'lng': -122.681785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.57057,
#        'lng': -122.681785}],
#      'distance': 5633,
#      'postalCode': '97217',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['Portland, OR 97217', 'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5b343650f2554e002c59304f',
#     'name': 'The Barley Pod',
#     'location': {'address': '6035 NE Halsey St',
#      'crossStreet': '60th and Halsey',
#      'lat': 45.53379954148548,
#      'lng': -122.60157058809958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.53379954148548,
#        'lng': -122.60157058809958}],
#      'distance': 5861,
#      'postalCode': '97213',
#      'cc': 'US',
#      'neighborhood': 'Rose City Park',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['6035 NE Halsey St (60th and Halsey)',
#       'Portland, OR 97213',
#       'United States']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4b72fd2df964a52027942de3',
#     'name': 'Migration Brewing',
#     'location': {'address': '2828 NE Glisan St',
#      'crossStreet': 'btwn NE 28th & NE 29th Ave',
#      'lat': 45.52628931783912,
#      'lng': -122.6363841873531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52628931783912,
#        'lng': -122.6363841873531}],
#      'distance': 3024,
#      'postalCode': '97232',
#      'cc': 'US',
#      'neighborhood': 'laurelh',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2828 NE Glisan St (btwn NE 28th & NE 29th Ave)',
#       'Portland, OR 97232',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '55fc84d2498e818369e083ce',
#     'name': 'Great Notion Brewing',
#     'location': {'address': '2204 NE Alberta St #101',
#      'crossStreet': 'at NE 22nd Ave',
#      'lat': 45.55888082414229,
#      'lng': -122.64277070760728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.55888082414229,
#        'lng': -122.64277070760728}],
#      'distance': 4949,
#      'postalCode': '97211',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2204 NE Alberta St #101 (at NE 22nd Ave)',
#       'Portland, OR 97211',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '49e18376f964a520d6611fe3',
#     'name': 'Hopworks Urban Brewery',
#     'location': {'address': '2944 SE Powell Blvd',
#      'crossStreet': 'at SE 29th Ave',
#      'lat': 45.49692767213002,
#      'lng': -122.63490786160365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.49692767213002,
#        'lng': -122.63490786160365}],
#      'distance': 4016,
#      'postalCode': '97202',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2944 SE Powell Blvd (at SE 29th Ave)',
#       'Portland, OR 97202',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4d7c44ea7498a1cd45237bfc',
#     'name': 'Hopworks BikeBar',
#     'location': {'address': '3947 N Williams Ave',
#      'crossStreet': 'btwn NE Shaver & NE Failing',
#      'lat': 45.55131640797111,
#      'lng': -122.66685119787043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.55131640797111,
#        'lng': -122.66685119787043}],
#      'distance': 3505,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['3947 N Williams Ave (btwn NE Shaver & NE Failing)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4f64f1e9e4b045fbd43e971d',
#     'name': 'Kells Brewery',
#     'location': {'address': '210 NW 21st Ave',
#      'crossStreet': 'at NW Everett St',
#      'lat': 45.524560726831375,
#      'lng': -122.69420977258888,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.524560726831375,
#        'lng': -122.69420977258888}],
#      'distance': 1633,
#      'postalCode': '97209',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['210 NW 21st Ave (at NW Everett St)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '48568d50f964a520b1501fe3',
#     'name': 'Old Town Brewing',
#     'location': {'address': '5201 NE M L King Blvd',
#      'crossStreet': 'at NE Sumner St',
#      'lat': 45.56060952611482,
#      'lng': -122.66195364581436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.56060952611482,
#        'lng': -122.66195364581436}],
#      'distance': 4593,
#      'postalCode': '97211',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['5201 NE M L King Blvd (at NE Sumner St)',
#       'Portland, OR 97211',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1388631',
#      'url': 'https://www.grubhub.com/restaurant/old-town-pizza--brewing-5201-ne-m-l-king-blvd-portland/1388631?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1388631',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '51530d2afe7023b29cc2c86c',
#     'name': 'Ecliptic Brewing',
#     'location': {'address': '825 N Cook St',
#      'crossStreet': 'at N Albina Ave',
#      'lat': 45.54732606869151,
#      'lng': -122.6750725507736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.54732606869151,
#        'lng': -122.6750725507736}],
#      'distance': 3015,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['825 N Cook St (at N Albina Ave)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '51751872'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '40be6a00f964a520cf001fe3',
#     'name': 'Rogue Ales Public House & Distillery',
#     'location': {'address': '1339 NW Flanders St',
#      'crossStreet': 'btwn NW 13th & NW 14th Ave',
#      'lat': 45.52580699142386,
#      'lng': -122.68498174742858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52580699142386,
#        'lng': -122.68498174742858}],
#      'distance': 1044,
#      'postalCode': '97209',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1339 NW Flanders St (btwn NW 13th & NW 14th Ave)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5b4151ad3b4e00002c1c0844',
#     'name': 'Backwoods Brewing Company',
#     'location': {'address': '231 NW 11th Ave',
#      'lat': 45.5249517,
#      'lng': -122.6823334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.5249517,
#        'lng': -122.6823334}],
#      'distance': 822,
#      'postalCode': '97209',
#      'cc': 'US',
#      'neighborhood': 'Pearl',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['231 NW 11th Ave',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5091f3c3e4b045f238951577',
#     'name': 'Base Camp Brewing',
#     'location': {'address': '930 SE Oak St',
#      'crossStreet': 'at SE 9th Ave',
#      'lat': 45.51989575341577,
#      'lng': -122.6564635365175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.51989575341577,
#        'lng': -122.6564635365175}],
#      'distance': 1383,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['930 SE Oak St (at SE 9th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4be8a5f2ee96c9282865febf',
#     'name': 'Hair of the Dog Brewery & Tasting Room',
#     'location': {'address': '61 SE Yamhill St',
#      'crossStreet': 'at SE Water Ave',
#      'lat': 45.515866354896026,
#      'lng': -122.66568159571948,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.515866354896026,
#        'lng': -122.66568159571948},
#       {'label': '?', 'lat': 45.515911, 'lng': -122.665627}],
#      'distance': 823,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['61 SE Yamhill St (at SE Water Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4a0f04b6f964a52018761fe3',
#     'name': 'Lucky Labrador Beer Hall',
#     'location': {'address': '1945 NW Quimby St',
#      'crossStreet': 'at NW 20th Ave',
#      'lat': 45.53367191634112,
#      'lng': -122.69186299637592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.53367191634112,
#        'lng': -122.69186299637592}],
#      'distance': 2032,
#      'postalCode': '97209',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1945 NW Quimby St (at NW 20th Ave)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5aebac6fb9b37b002c017f36',
#     'name': 'Little Beast Brewing Beer Garden',
#     'location': {'address': '3412 SE Division St',
#      'lat': 45.504604,
#      'lng': -122.62918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.504604,
#        'lng': -122.62918}],
#      'distance': 3919,
#      'postalCode': '97202',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['3412 SE Division St',
#       'Portland, OR 97202',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5340bdad498e87e5cd009a52',
#     'name': 'Baerlic Brewing',
#     'location': {'address': '2235 SE 11th Ave',
#      'crossStreet': 'at SE Sherman St',
#      'lat': 45.50673266449972,
#      'lng': -122.65476456768643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.50673266449972,
#        'lng': -122.65476456768643}],
#      'distance': 2135,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2235 SE 11th Ave (at SE Sherman St)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4bf05a14393fc9b6dcb3012b',
#     'name': 'Breakside Brewery',
#     'location': {'address': '820 NE Dekum St',
#      'crossStreet': 'at NE Durham St',
#      'lat': 45.57165267747703,
#      'lng': -122.65676234766916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.57165267747703,
#        'lng': -122.65676234766916}],
#      'distance': 5881,
#      'postalCode': '97211',
#      'cc': 'US',
#      'neighborhood': 'Woodlawn',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['820 NE Dekum St (at NE Durham St)',
#       'Portland, OR 97211',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '574e0f86498efe909e36d7bd',
#     'name': 'Wayfinder Beer',
#     'location': {'address': '304 SE 2nd Ave',
#      'crossStreet': 'Oak St',
#      'lat': 45.52056234539121,
#      'lng': -122.66345974438809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52056234539121,
#        'lng': -122.66345974438809}],
#      'distance': 838,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['304 SE 2nd Ave (Oak St)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '59402e6c8194fc347a820e62',
#     'name': 'Schilling Cider House Portland',
#     'location': {'address': '930 SE 10th Ave',
#      'lat': 45.51630468215655,
#      'lng': -122.6555846389145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.51630468215655,
#        'lng': -122.6555846389145},
#       {'label': '?', 'lat': 45.516207, 'lng': -122.655585}],
#      'distance': 1516,
#      'postalCode': '97214',
#      'cc': 'US',
#      'neighborhood': 'Buckman',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['930 SE 10th Ave',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '446538384'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '47f8f9c3f964a520cb4e1fe3',
#     'name': 'Rogue Eastside Pub & Pilot Brewery',
#     'location': {'address': '928 SE 9th Ave',
#      'crossStreet': 'at SE Belmont St',
#      'lat': 45.516230500599896,
#      'lng': -122.65663932116907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.516230500599896,
#        'lng': -122.65663932116907},
#       {'label': '?', 'lat': 45.516064, 'lng': -122.656591}],
#      'distance': 1440,
#      'postalCode': '97214',
#      'cc': 'US',
#      'neighborhood': 'Buckman',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['928 SE 9th Ave (at SE Belmont St)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '51a975a3498e3ea193bac733',
#     'name': "Reverend Nat's Hard Cider",
#     'location': {'address': '1813 NE 2nd Ave',
#      'crossStreet': 'at NE Schuyler St',
#      'lat': 45.5360508893186,
#      'lng': -122.6638311864513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.5360508893186,
#        'lng': -122.6638311864513}],
#      'distance': 1936,
#      'postalCode': '97212',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1813 NE 2nd Ave (at NE Schuyler St)',
#       'Portland, OR 97212',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '89064995'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5b55f3c360d11b002ce86879',
#     'name': 'West Coast Grocery Company',
#     'location': {'address': '1403 SE Stark St',
#      'crossStreet': 'at SE 14th Ave',
#      'lat': 45.5194182,
#      'lng': -122.651463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.5194182,
#        'lng': -122.651463}],
#      'distance': 1775,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1403 SE Stark St (at SE 14th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4a466c90f964a520d7a81fe3',
#     'name': 'Broadway Grill & Brewery',
#     'location': {'address': '1700 NE Broadway St',
#      'crossStreet': 'at NE 17th Ave',
#      'lat': 45.5349298200581,
#      'lng': -122.64823790736739,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.5349298200581,
#        'lng': -122.64823790736739}],
#      'distance': 2601,
#      'postalCode': '97232',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1700 NE Broadway St (at NE 17th Ave)',
#       'Portland, OR 97232',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2039141',
#      'url': 'https://www.grubhub.com/restaurant/broadway-grill--brewery-1700-ne-broadway-st-portland/2039141?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039141',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '94931954'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5281889d11d2efee20f08769',
#     'name': '13 Virtues Brewing Co.',
#     'location': {'address': '6410 SE Milwaukie Ave',
#      'crossStreet': 'btwn SE Henry St & SE Duke St',
#      'lat': 45.476208653334965,
#      'lng': -122.6488583947414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.476208653334965,
#        'lng': -122.6488583947414}],
#      'distance': 5285,
#      'postalCode': '97202',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['6410 SE Milwaukie Ave (btwn SE Henry St & SE Duke St)',
#       'Portland, OR 97202',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '84318764'},
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '40b13b00f964a520b0f51ee3',
#     'name': 'McMenamins Market Street Pub',
#     'location': {'address': '1526 SW 10th Ave',
#      'crossStreet': 'at SW Market St',
#      'lat': 45.51410379710902,
#      'lng': -122.68500717110815,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.51410379710902,
#        'lng': -122.68500717110815},
#       {'label': '?', 'lat': 45.514342, 'lng': -122.684992}],
#      'distance': 1085,
#      'postalCode': '97201',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1526 SW 10th Ave (at SW Market St)',
#       'Portland, OR 97201',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4eb5cfbf61af0dda90897210',
#     'name': 'Fire on the Mountain',
#     'location': {'address': '3443 NE 57th Ave',
#      'crossStreet': 'at NE Fremont St.',
#      'lat': 45.54806826722522,
#      'lng': -122.60489846135337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.54806826722522,
#        'lng': -122.60489846135337}],
#      'distance': 6228,
#      'postalCode': '97213',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['3443 NE 57th Ave (at NE Fremont St.)',
#       'Portland, OR 97213',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '57a40c49498e176e84c76cf7',
#     'name': 'Double Mountain Brewery & Taproom',
#     'location': {'address': '4336 SE Woodstock Blvd',
#      'crossStreet': 'at SE 44th Ave',
#      'lat': 45.47899930277078,
#      'lng': -122.6176625730897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.47899930277078,
#        'lng': -122.6176625730897}],
#      'distance': 6367,
#      'postalCode': '97206',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['4336 SE Woodstock Blvd (at SE 44th Ave)',
#       'Portland, OR 97206',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '539a2f31498e1b0751d1b49d',
#     'name': '10 Barrel Brewing',
#     'location': {'address': '1411 NW Flanders St',
#      'crossStreet': 'at NW 14th Ave',
#      'lat': 45.52590669558022,
#      'lng': -122.68547370421152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52590669558022,
#        'lng': -122.68547370421152}],
#      'distance': 1082,
#      'postalCode': '97209',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1411 NW Flanders St (at NW 14th Ave)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5a5eb2d8c58ed758fabddcd3',
#     'name': 'Modern Times Belmont Fermentorium',
#     'location': {'address': '630 SE Belmont St',
#      'crossStreet': 'at SE 6th Ave',
#      'lat': 45.516346406291866,
#      'lng': -122.65945672988892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.516346406291866,
#        'lng': -122.65945672988892}],
#      'distance': 1228,
#      'postalCode': '97214',
#      'cc': 'US',
#      'neighborhood': 'Buckman',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['630 SE Belmont St (at SE 6th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5340bc74498ed0ac7dbe8a90',
#     'name': 'Ex Novo Brewing',
#     'location': {'address': '2326 N Flint Ave',
#      'crossStreet': 'at NE Russell St',
#      'lat': 45.54004946052528,
#      'lng': -122.66858274397717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.54004946052528,
#        'lng': -122.66858274397717}],
#      'distance': 2247,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2326 N Flint Ave (at NE Russell St)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4c9a9c21a004a1cd15ed496e',
#     'name': 'Cascade Brewing Barrel House',
#     'location': {'address': '939 SE Belmont St',
#      'crossStreet': 'at SE 10th Ave',
#      'lat': 45.516603414049314,
#      'lng': -122.65583706093003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.516603414049314,
#        'lng': -122.65583706093003},
#       {'label': '?', 'lat': 45.516652, 'lng': -122.655937}],
#      'distance': 1488,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['939 SE Belmont St (at SE 10th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4a57e717f964a5200db71fe3',
#     'name': 'Fire on the Mountain',
#     'location': {'address': '1708 E Burnside St',
#      'crossStreet': 'at SE 17th Ave',
#      'lat': 45.52280324326804,
#      'lng': -122.64833222906537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52280324326804,
#        'lng': -122.64833222906537}],
#      'distance': 2037,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1708 E Burnside St (at SE 17th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '58b8f3162b04f876661f5274',
#     'name': 'Breakside Brewery',
#     'location': {'address': '1570 NW 22nd Ave',
#      'crossStreet': 'at NW Raleigh St',
#      'lat': 45.533924064136876,
#      'lng': -122.69646452792608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.533924064136876,
#        'lng': -122.69646452792608}],
#      'distance': 2309,
#      'postalCode': '97210',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1570 NW 22nd Ave (at NW Raleigh St)',
#       'Portland, OR 97210',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '52e97b0c498e684c472b97a8',
#     'name': 'StormBreaker Brewing',
#     'location': {'address': '832 N Beech St',
#      'crossStreet': 'at N Mississippi Ave',
#      'lat': 45.54953899078874,
#      'lng': -122.67543474571993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.54953899078874,
#        'lng': -122.67543474571993}],
#      'distance': 3262,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['832 N Beech St (at N Mississippi Ave)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '40b13b00f964a52045f51ee3',
#     'name': 'Barley Mill Pub',
#     'location': {'address': '1629 SE Hawthorne Blvd',
#      'crossStreet': 'at SE 17th Ave',
#      'lat': 45.512385,
#      'lng': -122.648854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.512385,
#        'lng': -122.648854},
#       {'label': '?', 'lat': 45.512303, 'lng': -122.648858}],
#      'distance': 2161,
#      'postalCode': '97214',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1629 SE Hawthorne Blvd (at SE 17th Ave)',
#       'Portland, OR 97214',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4ba0059af964a520105337e3',
#     'name': 'Lucky Labrador Tap Room',
#     'location': {'address': '1700 N Killingsworth St',
#      'crossStreet': 'btwn N Denver & N Interstate Ave',
#      'lat': 45.562610073498895,
#      'lng': -122.68518938805951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.562610073498895,
#        'lng': -122.68518938805951}],
#      'distance': 4793,
#      'postalCode': '97217',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['1700 N Killingsworth St (btwn N Denver & N Interstate Ave)',
#       'Portland, OR 97217',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4f9b9767121d8c8d0bd6ba5d',
#     'name': "Lemur's Sör Ház",
#     'location': {'address': '4635 NE 35th Ave',
#      'lat': 45.557264,
#      'lng': -122.628925,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.557264,
#        'lng': -122.628925},
#       {'label': '?', 'lat': 45.557259, 'lng': -122.628841}],
#      'distance': 5425,
#      'postalCode': '97211',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['4635 NE 35th Ave',
#       'Portland, OR 97211',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5aef4bc2cbcdee002c923eec',
#     'name': 'Great Notion Brewing',
#     'location': {'address': '2444 NW 28th Ave',
#      'lat': 45.53985226873808,
#      'lng': -122.70871081800976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.53985226873808,
#        'lng': -122.70871081800976}],
#      'distance': 3465,
#      'postalCode': '97210',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2444 NW 28th Ave',
#       'Portland, OR 97210',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5b4a4867d8096e002c629837',
#     'name': 'Ruse Brewing',
#     'location': {'address': '4784 SE 17th Ave',
#      'lat': 45.48765266491969,
#      'lng': -122.64842909876452,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.48765266491969,
#        'lng': -122.64842909876452},
#       {'label': '?', 'lat': 45.487916, 'lng': -122.648259}],
#      'distance': 4148,
#      'postalCode': '97202',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['4784 SE 17th Ave',
#       'Portland, OR 97202',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4f400f9be4b0e9ea79adf4f0',
#     'name': 'Gigantic Brewing Company',
#     'location': {'address': '5224 SE 26th Ave',
#      'lat': 45.48506024469774,
#      'lng': -122.63957690808608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.48506024469774,
#        'lng': -122.63957690808608},
#       {'label': '?', 'lat': 45.485053, 'lng': -122.639535}],
#      'distance': 4757,
#      'postalCode': '97202',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['5224 SE 26th Ave',
#       'Portland, OR 97202',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '4b1331cef964a5205a9523e3',
#     'name': 'Upright Brewing',
#     'location': {'address': '240 N Broadway',
#      'crossStreet': 'at N Ross Ave',
#      'lat': 45.53486001512325,
#      'lng': -122.66836560119364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.53486001512325,
#        'lng': -122.66836560119364}],
#      'distance': 1689,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['240 N Broadway (at N Ross Ave)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '540bd945498eadd8be83bdda',
#     'name': 'Culmination Brewing',
#     'location': {'address': '2117 NE Oregon St',
#      'crossStreet': 'at NE 21st Ave',
#      'lat': 45.52887661281229,
#      'lng': -122.64368983824339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52887661281229,
#        'lng': -122.64368983824339}],
#      'distance': 2565,
#      'postalCode': '97232',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['2117 NE Oregon St (at NE 21st Ave)',
#       'Portland, OR 97232',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '552c1e5e498e4130b1699eeb',
#     'name': 'Labrewatory',
#     'location': {'address': '670 N Russell St',
#      'crossStreet': 'Borthwick Ave',
#      'lat': 45.54088670024144,
#      'lng': -122.67325060306054,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.54088670024144,
#        'lng': -122.67325060306054}],
#      'distance': 2298,
#      'postalCode': '97227',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['670 N Russell St (Borthwick Ave)',
#       'Portland, OR 97227',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586493668',
#     'hasPerk': False},
#    {'id': '5a5eaeb959c42337c5f1c168',
#     'name': 'Von Ebert Brewing',
#     'location': {'address': '131 NW 13th Ave',
#      'crossStreet': 'at NW Davis St',
#      'lat': 45.52398,
#      'lng': -122.68469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.52398,
#        'lng': -122.68469}],
#      'distance': 917,
#      'postalCode': '97209',
#      'cc': 'US',
#      'neighborhood': 'Pearl',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['131 NW 13th Ave (at NW Davis St)',
#       'Portland, OR 97209',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '309412',
#      'url': 'https://www.grubhub.com/restaurant/von-ebert-brewing-131-nw-13th-avenue-portland/309412?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=309412',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1586493668',
#     'hasPerk': False}],
#   'confident': False}}

# %% [markdown]
# Among other things, we get a name, address, latitude and longitude for each microbrewery.
#
# Next we convert the data into a dataframe. We start by importing the json_normalize function we'll use to covert the data to table form.

# %%
from pandas.io.json import json_normalize

# %% [markdown]
# We set a variable equal to the segments of the Foursquare data that contain the information we want. We transform that to a pandas dataframe then examine the first few rows of the dataframe to see what we have.

# %%
brew = results['response']['venues']

brew_df = json_normalize(brew)

brew_df.head()
# Out:
#                          id                                         name  \
# 0  48837e4ef964a52036511fe3      Deschutes Brewery Portland Public House
# 1  5e486a88fda02b000899b294                   Gorges Beer: The Trailhead
# 2  5cbf7b91b399f7002c94b190                            Away Days Brewing
# 3  5b37dc162a7ab6002ca58d9f  Baerlic Brewing Beer Hall at the Barley Pod
# 4  5aadc02ee07550183870d5ee                                    10 Barrel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1586493668    False
# 1  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1586493668    False
# 2  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1586493668    False
# 3  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1586493668    False
# 4  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1586493668    False
#
#       location.address location.crossStreet  location.lat  location.lng  \
# 0      210 NW 11th Ave       at NW Davis St     45.524544   -122.681982
# 1    2705 SE Ankeny St                  NaN     45.522343   -122.638284
# 2     1516 SE 10th Ave                  NaN     45.511986   -122.655981
# 3    6035 NE Halsey St       at NE 60th Ave     45.533899   -122.601326
# 4  1 N Center Court St                  NaN     45.531254   -122.667361
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 45.52454408631625...  ...     United States
# 1  [{'label': 'display', 'lat': 45.522343, 'lng':...  ...     United States
# 2  [{'label': 'display', 'lat': 45.51198593825523...  ...     United States
# 3  [{'label': 'display', 'lat': 45.53389890556244...  ...     United States
# 4  [{'label': 'display', 'lat': 45.531254, 'lng':...  ...     United States
#
#                            location.formattedAddress venuePage.id delivery.id  \
# 0  [210 NW 11th Ave (at NW Davis St), Portland, O...     36780574         NaN
# 1  [2705 SE Ankeny St, Portland, OR 97214, United...          NaN         NaN
# 2  [1516 SE 10th Ave, Portland, OR 97214, United ...          NaN     1406736
# 3  [6035 NE Halsey St (at NE 60th Ave), Portland,...          NaN         NaN
# 4  [1 N Center Court St, Portland, OR 97227, Unit...          NaN         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2  https://www.grubhub.com/restaurant/away-days-b...                grubhub
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                delivery.provider.icon.name location.neighborhood
# 0                                      NaN                   NaN
# 1                                      NaN                   NaN
# 2  /delivery_provider_grubhub_20180129.png                   NaN
# 3                                      NaN                   NaN
# 4                                      NaN                   NaN
#
# [5 rows x 25 columns]

# %%
brew_df.shape
# Out:
# (50, 25)

# %% [markdown]
# We won't need all those columns to plot the microbrewery locations on a map. Let's select only the columns we'll need and drop the location. prefix from the column headings.

# %%
brew_df = brew_df[['name', 'location.address', 'location.lat', 'location.lng']]

brew_df.columns = [column.split('.')[-1] for column in brew_df.columns]

brew_df.head()
# Out:
#                                           name              address  \
# 0      Deschutes Brewery Portland Public House      210 NW 11th Ave
# 1                   Gorges Beer: The Trailhead    2705 SE Ankeny St
# 2                            Away Days Brewing     1516 SE 10th Ave
# 3  Baerlic Brewing Beer Hall at the Barley Pod    6035 NE Halsey St
# 4                                    10 Barrel  1 N Center Court St
#
#          lat         lng
# 0  45.524544 -122.681982
# 1  45.522343 -122.638284
# 2  45.511986 -122.655981
# 3  45.533899 -122.601326
# 4  45.531254 -122.667361

# %% [markdown]
# That's looking more like something we can work with. Let's check to see if we have empty cells or missing data.

# %%
brew_df.isnull().sum(axis = 0)
# Out:
# name       0
# address    1
# lat        0
# lng        0
# dtype: int64

# %% [markdown]
# Looks like we're missing just one address. We'll leave that one cell empty as the lat and lng is the critical information for our mapping project.
#
# Let's look at the data type to see if everything is in shape for mapping and calculations.

# %%
brew_df.dtypes
# Out:
# name        object
# address     object
# lat        float64
# lng        float64
# dtype: object

# %% [markdown]
# We need to convert the address column to string for use as labels in our map. The other data types look good for what we need.

# %%
brew_df.address = brew_df.address.astype(str)

# %% [markdown]
# Now we can plot our microbreweries on our Portland map and see where we are so far.

# %%
map_portland = folium.Map(location=[latitude, longitude], zoom_start = 11)

# add a red circle marker to represent downtown portland

folium.features.CircleMarker(
    [latitude, longitude],
    radius = 10,
    color ='red',
    popup ='PDX Downtown',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.5
).add_to(map_portland)

# add the micro breweries as blue circle markers

for lat, lng, label in zip(brew_df.lat, brew_df.lng, brew_df.address):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 5,
        color ='blue',
        popup = folium.Popup(label),
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.5
    ).add_to(map_portland)

map_portland
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Great. Now we have all the microbreweries within 6km of downtown Portland. We have the data we need and it's ready for analysis to create our report on prime locations for a new microbrewery!

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# For this project we're focusing on finding areas in Portland where the density of microbreweries is low. In particular, we're looking for areas where we can locate a new microbrewery more than 500 meters from a competitor. We're making the assumption that if an existing microbrewery is at least 500 meters from its nearest competitor then there is likely to be space for a new microbrewery.
#
# In the first step we collected the data we need for our analysis: the latitude and longitude of every microbrewery within 6km of downtown Portland (according to the Foursquare microbrewery category).
#
# The next step for our analysis is calculating the distances between our microbrewies and downtown Portland, as well as the distance from each microbrewery to its nearest competitor. We'll use that data to segment our microbreweries into clusters (using k-means clustering) so we can determine what regions of the city might be more promising for a new microbrewery.
#
# Our last step will focus on the most promising areas based on our k-means clustering analysis. We'll zero in on areas that meet requirements agreed to in discussion with our microbrewery entrepreneur. This will include areas where we are likely to find suitable and cost-effective locations that are more than 500 meters from any competitor. We'll prepare maps and tables of the locations that our client can use as a starting point for an 'on-the-ground' search of potential site locations.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# We want to be close enough to downtown Portland that our microbrewery is a viable option for travelers staying downtown, but not so close that we have multiple competitors less than 500 meters from us. So, let's calculate each microbrewery's distance from downtown. We'll use this data in our k-means analysis later on.
#
# We'll start by importing the GeoPy distance function. Next, we'll set our coordinates for downtown PDX we obtained earlier.

# %%
from geopy import distance

PDX = (45.5202471, -122.6741949)

# %% [markdown]
# To calculate the distances from the microbreweries to the center of Portland, we set up a *for loop*. In the *for loop* we run the distance function for each iteration of latitude and longitude. Then, we save the calculation to a list. Final, we print the list to confirm our results.

# %%
dist_PDX = []

for i in range(len(brew_df['lat'])):
    loc_i = (brew_df['lat'][i], brew_df['lng'][i])
    
    dist = round((distance.great_circle(PDX, loc_i).km), 1)
    
    dist_PDX.append(dist)
    
print(dist_PDX)
# Out:
# [0.8, 2.8, 1.7, 5.9, 1.3, 5.5, 5.6, 5.9, 3.0, 4.9, 4.0, 3.5, 1.6, 4.6, 3.0, 1.0, 0.8, 1.4, 0.8, 2.0, 3.9, 2.1, 5.9, 0.8, 1.5, 1.4, 1.9, 1.8, 2.6, 5.3, 1.1, 6.2, 6.4, 1.1, 1.2, 2.2, 1.5, 2.0, 2.3, 3.3, 2.2, 4.8, 5.4, 3.5, 4.1, 4.8, 1.7, 2.6, 2.3, 0.9]

# %% [markdown]
# We also want to know the distances between our microbreweries. We're looking for the closest competition for each microbrewery, noting especially if the competitor is within 500 meters of the microbrewery.
#
# To do this we set up two *for loops*. The first *for loop* is the base microbrewery we compare to all the other locations. Inside of it we set up a second *for loop* to iterate through the locations of all the microbreweries and run the distance function.
#
# We don't want to run the distance function for a microbrewery on itself, so we set up an *if* clause in the second *for loop* to check for this condition. Each time the second *for loop* finishes it adds the minimum distance found (one reason to bypass running the distance function for a microbrewery on itself) to a list. Finally, we print the list to confirm the results.

# %%
#PDX_long, PDX_lat = lonlat_to_xy(a, b)

nnbrew = []

for i in range(len(brew_df['lat'])):
    loc_i = (brew_df['lat'][i], brew_df['lng'][i])
    
    nnp = []
               
    for j in range(len(brew_df['lat'])):
        if j == i:
            pass
        else:
            loc_j = (brew_df['lat'][j], brew_df['lng'][j])
            rng = round((distance.great_circle(loc_i, loc_j).km), 2)
            nnp.append(rng)
    
    nnbrew.append(min(nnp))
    
print(nnbrew)
# Out:
# [0.05, 0.46, 0.47, 0.02, 0.41, 1.26, 0.92, 0.02, 0.46, 1.09, 0.96, 0.7, 0.7, 1.1, 0.25, 0.04, 0.05, 0.37, 0.49, 0.36, 0.96, 0.59, 1.29, 0.55, 0.04, 0.08, 0.38, 0.39, 0.76, 1.22, 1.1, 1.6, 1.84, 0.04, 0.22, 0.38, 0.04, 0.45, 0.36, 0.25, 0.56, 0.92, 1.09, 1.16, 0.75, 0.75, 0.38, 0.64, 0.38, 0.2]

# %% [markdown]
# Those distances look accurate.
#
# Next we want to add our distance calculations to our microbrewery dataframe. We'll do that by adding two new columns to the end of the dataframe. Then we'll view our progress.

# %%
brew_df['Dis from PDX Center'] = dist_PDX

brew_df['Closest Rival'] = nnbrew

brew_df.style

#print(brew_df.head())
# Out:
# <style  type="text/css" >
# </style><table id="T_9bce3e68_7ae5_11ea_84b4_645106acabbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >address</th>        <th class="col_heading level0 col2" >lat</th>        <th class="col_heading level0 col3" >lng</th>        <th class="col_heading level0 col4" >Dis from PDX Center</th>        <th class="col_heading level0 col5" >Closest Rival</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col0" class="data row0 col0" >Deschutes Brewery Portland Public House</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col1" class="data row0 col1" >210 NW 11th Ave</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col2" class="data row0 col2" >45.5245</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col3" class="data row0 col3" >-122.682</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col4" class="data row0 col4" >0.8</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow0_col5" class="data row0 col5" >0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col0" class="data row1 col0" >Gorges Beer: The Trailhead</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col1" class="data row1 col1" >2705 SE Ankeny St</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col2" class="data row1 col2" >45.5223</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col3" class="data row1 col3" >-122.638</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col4" class="data row1 col4" >2.8</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow1_col5" class="data row1 col5" >0.46</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col0" class="data row2 col0" >Away Days Brewing</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col1" class="data row2 col1" >1516 SE 10th Ave</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col2" class="data row2 col2" >45.512</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col3" class="data row2 col3" >-122.656</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col4" class="data row2 col4" >1.7</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow2_col5" class="data row2 col5" >0.47</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col0" class="data row3 col0" >Baerlic Brewing Beer Hall at the Barley Pod</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col1" class="data row3 col1" >6035 NE Halsey St</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col2" class="data row3 col2" >45.5339</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col3" class="data row3 col3" >-122.601</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col4" class="data row3 col4" >5.9</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow3_col5" class="data row3 col5" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col0" class="data row4 col0" >10 Barrel</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col1" class="data row4 col1" >1 N Center Court St</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col2" class="data row4 col2" >45.5313</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col3" class="data row4 col3" >-122.667</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col4" class="data row4 col4" >1.3</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow4_col5" class="data row4 col5" >0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col0" class="data row5 col0" >Leikam Tap Room</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col1" class="data row5 col1" >5812 E Burnside St</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col2" class="data row5 col2" >45.5226</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col3" class="data row5 col3" >-122.604</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col4" class="data row5 col4" >5.5</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow5_col5" class="data row5 col5" >1.26</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col0" class="data row6 col0" >Look Long Brewing Company</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col2" class="data row6 col2" >45.5706</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col3" class="data row6 col3" >-122.682</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col4" class="data row6 col4" >5.6</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow6_col5" class="data row6 col5" >0.92</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col0" class="data row7 col0" >The Barley Pod</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col1" class="data row7 col1" >6035 NE Halsey St</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col2" class="data row7 col2" >45.5338</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col3" class="data row7 col3" >-122.602</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col4" class="data row7 col4" >5.9</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow7_col5" class="data row7 col5" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow8_col0" class="data row8 col0" >Migration Brewing</td>
#                         <td id="T_9bce3e68_7ae5_11ea_84b4_645106acabbdrow8_col1" class="data row8 col1" >2828 NE Glisan St</td>

# %% [markdown]
# Nice.
#
# The distance calculations will be useful for partitioning our microbreweries through k-means clustering. We'll start by importing the Kmeans algorithm.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Next we'll drop the columns we don't need to run the algorithm and store the truncated dataframe in a variable. Then we'll run the algorithm on that variable. Based on inspection of the microbrewery map, fewer clusters seems better than more clusters.
#
# We're looking for real estate where we could locate a microbrewery close to downtown but at least 500 meters from the nearest competitor. Whether the distance is 500 meters or 750 meters is really moot, so partitioning our data into lots of group is overkill. We'll set our clusters, then, to three.
#
# Finally, we view the first ten labels generated by the algorithm.

# %%
# set number of clusters

PDX_clusters = brew_df.drop(['name', 'address', 'lat', 'lng'], 1)

# run k-means clustering
kmeans = KMeans(n_clusters = 3, random_state = 0).fit(PDX_clusters)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 0, 1, 2, 1, 2, 2, 2, 0, 2])

# %% [markdown]
# Now we'll add those labels to our main dataframe and inspect the results.

# %%
brew_df.insert(0, 'labels', kmeans.labels_)

brew_df
# Out:
#     labels                                         name  \
# 0        1      Deschutes Brewery Portland Public House
# 1        0                   Gorges Beer: The Trailhead
# 2        1                            Away Days Brewing
# 3        2  Baerlic Brewing Beer Hall at the Barley Pod
# 4        1                                    10 Barrel
# 5        2                              Leikam Tap Room
# 6        2                    Look Long Brewing Company
# 7        2                               The Barley Pod
# 8        0                            Migration Brewing
# 9        2                         Great Notion Brewing
# 10       0                       Hopworks Urban Brewery
# 11       0                             Hopworks BikeBar
# 12       1                                Kells Brewery
# 13       2                             Old Town Brewing
# 14       0                             Ecliptic Brewing
# 15       1         Rogue Ales Public House & Distillery
# 16       1                    Backwoods Brewing Company
# 17       1                            Base Camp Brewing
# 18       1       Hair of the Dog Brewery & Tasting Room
# 19       1                     Lucky Labrador Beer Hall
# 20       0             Little Beast Brewing Beer Garden
# 21       1                              Baerlic Brewing
# 22       2                            Breakside Brewery
# 23       1                               Wayfinder Beer
# 24       1               Schilling Cider House Portland
# 25       1           Rogue Eastside Pub & Pilot Brewery
# 26       1                    Reverend Nat's Hard Cider
# 27       1                   West Coast Grocery Company
# 28       0                     Broadway Grill & Brewery
# 29       2                       13 Virtues Brewing Co.
# 30       1                 McMenamins Market Street Pub
# 31       2                         Fire on the Mountain
# 32       2            Double Mountain Brewery & Taproom
# 33       1                            10 Barrel Brewing
# 34       1            Modern Times Belmont Fermentorium
# 35       1                              Ex Novo Brewing
# 36       1                 Cascade Brewing Barrel House
# 37       1                         Fire on the Mountain
# 38       1                            Breakside Brewery
# 39       0                         StormBreaker Brewing
# 40       1                              Barley Mill Pub
# 41       2                      Lucky Labrador Tap Room
# 42       2                              Lemur's Sör Ház
# 43       0                         Great Notion Brewing
# 44       0                                 Ruse Brewing
# 45       2                     Gigantic Brewing Company
# 46       1                              Upright Brewing
# 47       0                          Culmination Brewing
# 48       1                                  Labrewatory
# 49       1                            Von Ebert Brewing
#
#                     address        lat         lng  Dis from PDX Center  \
# 0           210 NW 11th Ave  45.524544 -122.681982                  0.8
# 1         2705 SE Ankeny St  45.522343 -122.638284                  2.8
# 2          1516 SE 10th Ave  45.511986 -122.655981                  1.7
# 3         6035 NE Halsey St  45.533899 -122.601326                  5.9
# 4       1 N Center Court St  45.531254 -122.667361                  1.3
# 5        5812 E Burnside St  45.522624 -122.604116                  5.5
# 6                       NaN  45.570570 -122.681785                  5.6
# 7         6035 NE Halsey St  45.533800 -122.601571                  5.9
# 8         2828 NE Glisan St  45.526289 -122.636384                  3.0
# 9   2204 NE Alberta St #101  45.558881 -122.642771                  4.9
# 10      2944 SE Powell Blvd  45.496928 -122.634908                  4.0
# 11      3947 N Williams Ave  45.551316 -122.666851                  3.5
# 12          210 NW 21st Ave  45.524561 -122.694210                  1.6
# 13    5201 NE M L King Blvd  45.560610 -122.661954                  4.6
# 14            825 N Cook St  45.547326 -122.675073                  3.0
# 15      1339 NW Flanders St  45.525807 -122.684982                  1.0
# 16          231 NW 11th Ave  45.524952 -122.682333                  0.8
# 17            930 SE Oak St  45.519896 -122.656464                  1.4
# 18         61 SE Yamhill St  45.515866 -122.665682                  0.8
# 19        1945 NW Quimby St  45.533672 -122.691863                  2.0
# 20      3412 SE Division St  45.504604 -122.629180                  3.9
# 21         2235 SE 11th Ave  45.506733 -122.654765                  2.1
# 22          820 NE Dekum St  45.571653 -122.656762                  5.9
# 23           304 SE 2nd Ave  45.520562 -122.663460                  0.8
# 24          930 SE 10th Ave  45.516305 -122.655585                  1.5
# 25           928 SE 9th Ave  45.516231 -122.656639                  1.4
# 26          1813 NE 2nd Ave  45.536051 -122.663831                  1.9
# 27         1403 SE Stark St  45.519418 -122.651463                  1.8
# 28      1700 NE Broadway St  45.534930 -122.648238                  2.6
# 29    6410 SE Milwaukie Ave  45.476209 -122.648858                  5.3
# 30         1526 SW 10th Ave  45.514104 -122.685007                  1.1
# 31         3443 NE 57th Ave  45.548068 -122.604898                  6.2
# 32   4336 SE Woodstock Blvd  45.478999 -122.617663                  6.4
# 33      1411 NW Flanders St  45.525907 -122.685474                  1.1
# 34        630 SE Belmont St  45.516346 -122.659457                  1.2
# 35         2326 N Flint Ave  45.540049 -122.668583                  2.2
# 36        939 SE Belmont St  45.516603 -122.655837                  1.5
# 37       1708 E Burnside St  45.522803 -122.648332                  2.0
# 38         1570 NW 22nd Ave  45.533924 -122.696465                  2.3
# 39           832 N Beech St  45.549539 -122.675435                  3.3
# 40   1629 SE Hawthorne Blvd  45.512385 -122.648854                  2.2
# 41  1700 N Killingsworth St  45.562610 -122.685189                  4.8
# 42         4635 NE 35th Ave  45.557264 -122.628925                  5.4
# 43         2444 NW 28th Ave  45.539852 -122.708711                  3.5
# 44         4784 SE 17th Ave  45.487653 -122.648429                  4.1
# 45         5224 SE 26th Ave  45.485060 -122.639577                  4.8
# 46           240 N Broadway  45.534860 -122.668366                  1.7
# 47        2117 NE Oregon St  45.528877 -122.643690                  2.6
# 48         670 N Russell St  45.540887 -122.673251                  2.3
# 49          131 NW 13th Ave  45.523980 -122.684690                  0.9
#
#     Closest Rival
# 0            0.05
# 1            0.46
# 2            0.47
# 3            0.02
# 4            0.41
# 5            1.26
# 6            0.92
# 7            0.02
# 8            0.46
# 9            1.09
# 10           0.96
# 11           0.70
# 12           0.70
# 13           1.10
# 14           0.25
# 15           0.04
# 16           0.05
# 17           0.37
# 18           0.49
# 19           0.36
# 20           0.96
# 21           0.59
# 22           1.29
# 23           0.55
# 24           0.04
# 25           0.08
# 26           0.38
# 27           0.39
# 28           0.76
# 29           1.22
# 30           1.10
# 31           1.60
# 32           1.84
# 33           0.04
# 34           0.22
# 35           0.38
# 36           0.04
# 37           0.45
# 38           0.36
# 39           0.25
# 40           0.56
# 41           0.92
# 42           1.09
# 43           1.16
# 44           0.75
# 45           0.75
# 46           0.38
# 47           0.64
# 48           0.38
# 49           0.20

# %% [markdown]
# Let's see how many microbreweries are in each of clusters.

# %%
brew_df['labels'].value_counts()
# Out:
# 1    26
# 2    13
# 0    11
# Name: labels, dtype: int64

# %% [markdown]
# I suspect the largest cluster is the group of microbreweries packed around downtown Portland. The other two clusters are more likely to be areas of interest to our microbrewery entreprenuers. Let's map our microbreweries again with a different color for each cluster to find out.
#
# To assign a different color for each cluster we write a *for loop* that detects the label through a series of *if* statments that assigns the appropriate cluster color to the label.

# %%
map_cluster = folium.Map(location = PDX, zoom_start=12)

folium.features.CircleMarker(PDX,
    radius = 10,
    color ='red',
    popup ='PDX Downtown',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.5
).add_to(map_cluster)

# add markers to the map
#markers_colors = []

for lat, lon, cluster in zip(brew_df['lat'], brew_df['lng'],\
                                  brew_df['labels']):
        
        if cluster == 1:
            folium.CircleMarker([lat, lon],
            radius = 5,
            color = 'blue',
            fill = True,
            fill_color = 'blue',
            fill_opacity = 0.7).add_to(map_cluster)
            
        elif cluster == 2:
            folium.CircleMarker([lat, lon],
            radius = 5,
            color = 'red',
            fill = True,
            fill_color = 'red',
            fill_opacity = 0.7).add_to(map_cluster)
        
        else:
            folium.CircleMarker([lat, lon],
            radius = 5,
            color = 'green',
            fill = True,
            fill_color = 'green',
            fill_opacity = 0.7).add_to(map_cluster)
        
map_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Indeed, our largest cluster (designated in blue in the map) looks to be packed around downtown Portland. Our red and green clusters are further away from downtown and they are more spread out. These areas will be of more interest to our microbrewery entreprenuers.
#
# Let's make tables of the red and green clusters that include the name, address, latitude and longitude of the microbreweries in each cluster. We'll provide these to our entrepreneurs as a starting point for further research.

# %%
import pandas as pd

red_c = brew_df[brew_df.labels == 2]

red_cs = red_c.sort_values(by = ['Closest Rival'], axis = 0, ascending = False).reset_index(drop = True)

red_cs.style
# Out:
# <style  type="text/css" >
# </style><table id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >labels</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >Dis from PDX Center</th>        <th class="col_heading level0 col6" >Closest Rival</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col0" class="data row0 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col1" class="data row0 col1" >Double Mountain Brewery & Taproom</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col2" class="data row0 col2" >4336 SE Woodstock Blvd</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col3" class="data row0 col3" >45.479</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col4" class="data row0 col4" >-122.618</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col5" class="data row0 col5" >6.4</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow0_col6" class="data row0 col6" >1.84</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col1" class="data row1 col1" >Fire on the Mountain</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col2" class="data row1 col2" >3443 NE 57th Ave</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col3" class="data row1 col3" >45.5481</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col4" class="data row1 col4" >-122.605</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col5" class="data row1 col5" >6.2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow1_col6" class="data row1 col6" >1.6</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col1" class="data row2 col1" >Breakside Brewery</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col2" class="data row2 col2" >820 NE Dekum St</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col3" class="data row2 col3" >45.5717</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col4" class="data row2 col4" >-122.657</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col5" class="data row2 col5" >5.9</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow2_col6" class="data row2 col6" >1.29</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col1" class="data row3 col1" >Leikam Tap Room</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col2" class="data row3 col2" >5812 E Burnside St</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col3" class="data row3 col3" >45.5226</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col4" class="data row3 col4" >-122.604</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col5" class="data row3 col5" >5.5</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow3_col6" class="data row3 col6" >1.26</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col0" class="data row4 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col1" class="data row4 col1" >13 Virtues Brewing Co.</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col2" class="data row4 col2" >6410 SE Milwaukie Ave</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col3" class="data row4 col3" >45.4762</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col4" class="data row4 col4" >-122.649</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col5" class="data row4 col5" >5.3</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow4_col6" class="data row4 col6" >1.22</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col1" class="data row5 col1" >Old Town Brewing</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col2" class="data row5 col2" >5201 NE M L King Blvd</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col3" class="data row5 col3" >45.5606</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col4" class="data row5 col4" >-122.662</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col5" class="data row5 col5" >4.6</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow5_col6" class="data row5 col6" >1.1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col0" class="data row6 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col1" class="data row6 col1" >Great Notion Brewing</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col2" class="data row6 col2" >2204 NE Alberta St #101</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col3" class="data row6 col3" >45.5589</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col4" class="data row6 col4" >-122.643</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col5" class="data row6 col5" >4.9</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow6_col6" class="data row6 col6" >1.09</td>
#             </tr>
#             <tr>
#                         <th id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow7_col0" class="data row7 col0" >2</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106acabbdrow7_col1" class="data row7 col1" >Lemur's Sör Ház</td>
#                         <td id="T_c1efddf6_7ae5_11ea_8e2e_645106ac

# %% [markdown]
# We want to give our entrepreuners areas where the next closest brewery is more than 500 meters away. Looks like every microbrewery on this list fits that description, except the last two. Based on the name and address, this is one brewery, so we'll drop one.
#
# We'll save the resulting dataframe as a .csv file so we can send it our client.

# %%
red_cs.drop([red_cs.index[12]], inplace = True)

red_cs.to_csv('brew_red_cluster.csv')

red_cs.style
# Out:
# <style  type="text/css" >
# </style><table id="T_c4f970e8_7ae5_11ea_9e71_645106acabbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >labels</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >Dis from PDX Center</th>        <th class="col_heading level0 col6" >Closest Rival</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col0" class="data row0 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col1" class="data row0 col1" >Double Mountain Brewery & Taproom</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col2" class="data row0 col2" >4336 SE Woodstock Blvd</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col3" class="data row0 col3" >45.479</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col4" class="data row0 col4" >-122.618</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col5" class="data row0 col5" >6.4</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow0_col6" class="data row0 col6" >1.84</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col1" class="data row1 col1" >Fire on the Mountain</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col2" class="data row1 col2" >3443 NE 57th Ave</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col3" class="data row1 col3" >45.5481</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col4" class="data row1 col4" >-122.605</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col5" class="data row1 col5" >6.2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow1_col6" class="data row1 col6" >1.6</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col1" class="data row2 col1" >Breakside Brewery</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col2" class="data row2 col2" >820 NE Dekum St</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col3" class="data row2 col3" >45.5717</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col4" class="data row2 col4" >-122.657</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col5" class="data row2 col5" >5.9</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow2_col6" class="data row2 col6" >1.29</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col1" class="data row3 col1" >Leikam Tap Room</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col2" class="data row3 col2" >5812 E Burnside St</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col3" class="data row3 col3" >45.5226</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col4" class="data row3 col4" >-122.604</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col5" class="data row3 col5" >5.5</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow3_col6" class="data row3 col6" >1.26</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col0" class="data row4 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col1" class="data row4 col1" >13 Virtues Brewing Co.</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col2" class="data row4 col2" >6410 SE Milwaukie Ave</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col3" class="data row4 col3" >45.4762</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col4" class="data row4 col4" >-122.649</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col5" class="data row4 col5" >5.3</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow4_col6" class="data row4 col6" >1.22</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col1" class="data row5 col1" >Old Town Brewing</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col2" class="data row5 col2" >5201 NE M L King Blvd</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col3" class="data row5 col3" >45.5606</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col4" class="data row5 col4" >-122.662</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col5" class="data row5 col5" >4.6</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow5_col6" class="data row5 col6" >1.1</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col0" class="data row6 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col1" class="data row6 col1" >Great Notion Brewing</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col2" class="data row6 col2" >2204 NE Alberta St #101</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col3" class="data row6 col3" >45.5589</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col4" class="data row6 col4" >-122.643</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col5" class="data row6 col5" >4.9</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow6_col6" class="data row6 col6" >1.09</td>
#             </tr>
#             <tr>
#                         <th id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow7_col0" class="data row7 col0" >2</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106acabbdrow7_col1" class="data row7 col1" >Lemur's Sör Ház</td>
#                         <td id="T_c4f970e8_7ae5_11ea_9e71_645106ac

# %% [markdown]
# Let's create a map that includes only the microbreweries on our final red cluster list. We'll save this map so we can give it our client as well.

# %%
map_red_cluster = folium.Map(location=[latitude, longitude], zoom_start = 12)

# add a blue circle marker to represent downtown portland

folium.features.CircleMarker(
    [latitude, longitude],
    radius = 10,
    color ='blue',
    popup ='PDX Downtown',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.5
).add_to(map_red_cluster)

# add our red cluster with red circle markers

for lat, lng, label in zip(red_cs.lat, red_cs.lng, red_cs.address):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 5,
        color ='red',
        popup = folium.Popup(label),
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.5
    ).add_to(map_red_cluster)

map_red_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_red_cluster.save('map_red_cluster.html')

# %% [markdown]
# Let's create a similar table for our green cluster.

# %%
green_c = brew_df[brew_df.labels == 0]

green_cs = green_c.sort_values(by = ['Closest Rival'], ascending = False).reset_index(drop = True)

green_cs.style
# Out:
# <style  type="text/css" >
# </style><table id="T_dba16b86_7ae5_11ea_b137_645106acabbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >labels</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >Dis from PDX Center</th>        <th class="col_heading level0 col6" >Closest Rival</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col1" class="data row0 col1" >Great Notion Brewing</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col2" class="data row0 col2" >2444 NW 28th Ave</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col3" class="data row0 col3" >45.5399</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col4" class="data row0 col4" >-122.709</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col5" class="data row0 col5" >3.5</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow0_col6" class="data row0 col6" >1.16</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col1" class="data row1 col1" >Hopworks Urban Brewery</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col2" class="data row1 col2" >2944 SE Powell Blvd</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col3" class="data row1 col3" >45.4969</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col4" class="data row1 col4" >-122.635</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col5" class="data row1 col5" >4</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow1_col6" class="data row1 col6" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col1" class="data row2 col1" >Little Beast Brewing Beer Garden</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col2" class="data row2 col2" >3412 SE Division St</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col3" class="data row2 col3" >45.5046</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col4" class="data row2 col4" >-122.629</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col5" class="data row2 col5" >3.9</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow2_col6" class="data row2 col6" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col1" class="data row3 col1" >Broadway Grill & Brewery</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col2" class="data row3 col2" >1700 NE Broadway St</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col3" class="data row3 col3" >45.5349</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col4" class="data row3 col4" >-122.648</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col5" class="data row3 col5" >2.6</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow3_col6" class="data row3 col6" >0.76</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col1" class="data row4 col1" >Ruse Brewing</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col2" class="data row4 col2" >4784 SE 17th Ave</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col3" class="data row4 col3" >45.4877</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col4" class="data row4 col4" >-122.648</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col5" class="data row4 col5" >4.1</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow4_col6" class="data row4 col6" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col1" class="data row5 col1" >Hopworks BikeBar</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col2" class="data row5 col2" >3947 N Williams Ave</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col3" class="data row5 col3" >45.5513</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col4" class="data row5 col4" >-122.667</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col5" class="data row5 col5" >3.5</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow5_col6" class="data row5 col6" >0.7</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col1" class="data row6 col1" >Culmination Brewing</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col2" class="data row6 col2" >2117 NE Oregon St</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col3" class="data row6 col3" >45.5289</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col4" class="data row6 col4" >-122.644</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col5" class="data row6 col5" >2.6</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow6_col6" class="data row6 col6" >0.64</td>
#             </tr>
#             <tr>
#                         <th id="T_dba16b86_7ae5_11ea_b137_645106acabbdlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow7_col0" class="data row7 col0" >0</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106acabbdrow7_col1" class="data row7 col1" >Gorges Beer: The Trailhead</td>
#                         <td id="T_dba16b86_7ae5_11ea_b137_645106

# %% [markdown]
# Looks like we have more microbreweries on this list that are closer together than 500 meters. Let's drop those rows from our final table.
#
# Again, we'll save the final table to share with our client.

# %%
green_cs.drop(green_cs[green_cs['Closest Rival'] < .5].index, inplace = True)

green_cs.to_csv('brew_green_cluster.csv')

green_cs.style
# Out:
# <style  type="text/css" >
# </style><table id="T_de4c7706_7ae5_11ea_95a2_645106acabbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >labels</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >Dis from PDX Center</th>        <th class="col_heading level0 col6" >Closest Rival</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col1" class="data row0 col1" >Great Notion Brewing</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col2" class="data row0 col2" >2444 NW 28th Ave</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col3" class="data row0 col3" >45.5399</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col4" class="data row0 col4" >-122.709</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col5" class="data row0 col5" >3.5</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow0_col6" class="data row0 col6" >1.16</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col1" class="data row1 col1" >Hopworks Urban Brewery</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col2" class="data row1 col2" >2944 SE Powell Blvd</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col3" class="data row1 col3" >45.4969</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col4" class="data row1 col4" >-122.635</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col5" class="data row1 col5" >4</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow1_col6" class="data row1 col6" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col1" class="data row2 col1" >Little Beast Brewing Beer Garden</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col2" class="data row2 col2" >3412 SE Division St</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col3" class="data row2 col3" >45.5046</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col4" class="data row2 col4" >-122.629</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col5" class="data row2 col5" >3.9</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow2_col6" class="data row2 col6" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col1" class="data row3 col1" >Broadway Grill & Brewery</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col2" class="data row3 col2" >1700 NE Broadway St</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col3" class="data row3 col3" >45.5349</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col4" class="data row3 col4" >-122.648</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col5" class="data row3 col5" >2.6</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow3_col6" class="data row3 col6" >0.76</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col1" class="data row4 col1" >Ruse Brewing</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col2" class="data row4 col2" >4784 SE 17th Ave</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col3" class="data row4 col3" >45.4877</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col4" class="data row4 col4" >-122.648</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col5" class="data row4 col5" >4.1</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow4_col6" class="data row4 col6" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col1" class="data row5 col1" >Hopworks BikeBar</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col2" class="data row5 col2" >3947 N Williams Ave</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col3" class="data row5 col3" >45.5513</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col4" class="data row5 col4" >-122.667</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col5" class="data row5 col5" >3.5</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow5_col6" class="data row5 col6" >0.7</td>
#             </tr>
#             <tr>
#                         <th id="T_de4c7706_7ae5_11ea_95a2_645106acabbdlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col1" class="data row6 col1" >Culmination Brewing</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col2" class="data row6 col2" >2117 NE Oregon St</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col3" class="data row6 col3" >45.5289</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col4" class="data row6 col4" >-122.644</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col5" class="data row6 col5" >2.6</td>
#                         <td id="T_de4c7706_7ae5_11ea_95a2_645106acabbdrow6_col6" class="data row6 col6" >0.64</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Finally, we'll create a map for our green cluster and save it.

# %%
map_green_cluster = folium.Map(location=[latitude, longitude], zoom_start = 12)

# add a blue circle marker to represent downtown portland

folium.features.CircleMarker(
    [latitude, longitude],
    radius = 10,
    color ='blue',
    popup ='PDX Downtown',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.5
).add_to(map_green_cluster)

# add our red cluster with red circle markers

for lat, lng, label in zip(green_cs.lat, green_cs.lng, green_cs.address):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 5,
        color ='green',
        popup = folium.Popup(label),
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.5
    ).add_to(map_green_cluster)

map_green_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_green_cluster.save('map_green_cluster.html')

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# The analysis illlustrates that microbreweries in Portland are more densely distributed the closer we get to the center of downtown. The NE and SE neighborhood areas exhibit multiple areas where microbreweries are less densely distributed, thus holding the most promise for establishing a new microbrewery without a nearby competitor.
#
# Narrowing our focus to the microbreweries in NE and SE Portland, we filtered out all microbreweries that had a competitor within 500 meters. The remaining microbreweries represent areas of lower competition for customers. These areas look particularly attractive because in the past five years the neighborhoods have seen renewed property development and renovation. Additionally, real estate in downtown Portland may be overdeveloped. Property in the surrounding neighborhoods could be obtained at a discount relative to downtown, providing a competitive advantage to a new microbrewery.
#
# The best candidates for locating a new microbrewery are represented by the green and red clusters on our maps. These maps, and the tables used to generate them, are stored and available for our client's use. This information, however, should be supplemented by additional data relevant to selecting a prime location for a new microbrewery. The objective of this report is to identify areas where microbreweries appear not to be overcrowded. Certainly, an entrepreneur would want to look at real estate prices, zoning laws, available parking, etc., to determine if any of the locations identified through our analysis would be suitable. Our client should therefore use our recommendations as a starting point for more detailed analysis that could result in a location that has both no nearby competitors and several other factors in its favor.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The focus of this project was to assist our client by narrowing their search for a prime location for a new microbrewery. By mapping the location of existing microbreweries provided through Foursquare data we got a general idea that microbreweries are concentrated around downtown Portland, with less density in the neighborhoods that surround downtown. K-means clustering generated promising locations in the surrounding neighborhoods in NE and SE Portland. Those clusters were further refined to create maps and a table of addresses for further exploration by the client.
#
# A final decision on a prime location for a microbrewery should consider the location analysis in the project. Our client should also consider a number of other relevent factors, such real estate availability and price, current trends in the microbrewery market and neighborhood social and economic factors, when making a final decision. Those additional factors are beyond the scope of this project, the purpose of which was to analyze relative location of existing microbreweries near downtown Portland.
